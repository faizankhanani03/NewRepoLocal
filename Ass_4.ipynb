# %%
print("hallo world")
# Out:
# hallo world

# %%
print("this is feauture1"),("world") ("dropdown")
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\user\AppData\Local\Temp\ipykernel_11052\5634213.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print("this is feauture1"),("world") ("")
# this is feauture1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("this is feauture1"),("world") ("")
#
# TypeError: 'str' object is not callable
