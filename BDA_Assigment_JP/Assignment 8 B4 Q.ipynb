# %% [markdown]
# Q1. Write a Python function called add_numbers that takes two numbers as arguments and returns their sum. Then, test the function by calling it with two numbers of your choice.

# %%
def add_num(a, b):
    return a + b

result = add_num(5, 25)
print(result)
# Out:
# 30

# %% [markdown]
# Q2. Write a Python function count_vowels that accepts a string and returns the number of vowels a, e, i, o, u, A, E, I, O, U in that string.
#
# - Example: 'Welcome'
# - Output: 3 vowels

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"   
    count = 0               
    
    for vowel in text:       
        if vowel in vowels:  
            count += 1
    
    return count


word = "Welcome"
print("Total vowels in", word, count_vowels(word))
# Out:
# Total vowels in Welcome 3

# %% [markdown]
# Q3. Create a Python function called currency_converter() that takes two arguments:
#
# - amount: The amount of money to be converted (in USD).
# - exchange_rate (default is 280): The conversion rate from USD to another currency (e.g., PKR). You can assume the default rate is 1 USD = 280 PKR.
# -
# The function should return a message showing how much the given amount is worth in the target currency (PKR).
#
# Expected Output:
#
# '100 USD is equivalent to 28000 PKR'

# %%
def currency_converter(amount, exchange_rate=280):
    converted = amount * exchange_rate
    message = f"{amount} USD is equivalent {converted} PKR"
    return message
print(currency_converter(100))
# Out:
# 100 USD is equivalent 28000 PKR

# %% [markdown]
# Q4. Write a Python function display_student_info that accepts the following details about a student:
#
# - name (Keyword argument): The name of the student.
# - age (Keyword argument): The age of the student.
# - grade (Keyword argument): The grade the student is in.
# - school (Keyword argument): The name of the school the student attends.
#
# Expected Output:
#
# - Name: John Doe
# - Age: 15
# - Grade: 10th
# - School: Greenwood High

# %%
def student_info (name,age,grade,school):
    print("name:" ,name)
    print("Age:" ,age)
    print("grade:", grade)
    print("school:" ,school)
student_info(name='John Doe',age=15,grade='10th',school='Greenwood High')
# Out:
# name: John Doe
# Age: 15
# grade: 10th
# school: Greenwood High

# %% [markdown]
# Q5. Write a Python function calculate_price that accepts two positional arguments:
#
# - price: The price of a single item.
# - quantity: The number of items bought.
# - The function should return the total price by multiplying price and quantity.

# %%
def calculate_price(price,qty):
    print('Price:', price)
    print('Qty:', qty)
    return price * qty

calculate_price(200,2)
# Out:
# Price: 200
# Qty: 2
# 400

# %% [markdown]
# Q6. Write a Python function display_prices that takes a product name and an arbitrary number of keyword arguments representing product prices. The function should display each product and its price.
#
# Expected Output:
#
# Product: Laptop
#
# Amazon: $800
#
# eBay: $750
#
# Walmart: $780

# %%
def dispaly_price(product , **kwargs):
    print(f"Product: {product}\n")
    for platform , price in kwargs.items():
        print(f"{platform}:  {price}\n" )

dispaly_price(product= 'Laptop',amazon='$800', ebay= '$750' , walmart= '780')
# Out:
# Product: Laptop
#
# amazon:  $800
#
# ebay:  $750
#
# walmart:  780

# %% [markdown]
# Q7. Write a Python function find_max that takes arbitrary n umber of positional arguments and returns the maximum number.

# %%
def find_max(*args):
    max_num = args[0]
    for num in args:
        if num > max_num:
            max_num = num
    return max_num

print(find_max(1,5,3,9,100,500,320))
# Out:
# 500

# %% [markdown]
# Q8.
#
# Write a Python function calculate_rectangle that accepts the length and width of a rectangle as arguments. Inside this function, create two nested functions:
#
# - calculate_area: This function should calculate the area of the rectangle.
# - calculate_perimeter: This function should calculate the perimeter of the rectangle.
# - The main function should return both the area and the perimeter of the rectangle.
#
# Expected Output:
#
# Area: 15
#
# Perimeter: 16

# %%
def calculate_rectangle(lenght , width):
    def calculate_area():
        return lenght * width
    
    def calculate_perimiter():
        return 2 * (lenght + width)
    
    return calculate_area() , calculate_perimiter() 
area , perimeter = calculate_rectangle(3, 5)
print('Area:', area)
print('Perimeter:' , perimeter)
# Out:
# Area: 15
# Perimeter: 16

# %% [markdown]
# Q9. Write a Python function taxi_fare(distance, rate=100) that calculates the taxi fare.
# The default rate is 100 PKR per km, but the user can also enter a custom rate.
#
# FORMULA: distance * rate
#
# Expected Output:
#
# - Taxi fare for 10 km = 1000 PKR (using default parameter)
# - Taxi fare for 15 km = 1800 PKR (custom rate)

# %%
def taxi_fare(distance , rate = 100):
    fare = distance * rate
    message = (f"Taxi fare for {distance} km = {fare} PKR")
    return message
print(taxi_fare(50 , 500))
print(taxi_fare(10))
# Out:
# Taxi fare for 50 km = 25000 PKR
# Taxi fare for 10 km = 1000 PKR

# %% [markdown]
# Q10.
#
# Write a Python function shopping_bill(price, quantity, discount=0) that uses nested functions:
#
# - An inner function calculate_total() → multiplies price * quantity.
# - An inner function apply_discount(total) → subtracts discount from total (but never below 0).
#
# The outer function should return the final bill amount.
#
# Expected Output:
#
# - Final Bill = 600 PKR (no discount)
# - Final Bill = 500 PKR (with discount)

# %%
def resturant_bill(price , quanitity , discount = 0):
    def calculate_total():
        return price * quanitity

    def discounted(total):
        with_discount = total - discount
        return with_discount if with_discount > 0 else 0
        
    
    total = calculate_total()
    bill = discounted(total)
    return bill

print(resturant_bill(50,5))
print(resturant_bill(50,5,100))
# Out:
# 250
# 150
