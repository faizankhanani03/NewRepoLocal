# %% [markdown]
# Q1. Write a Python program that prints the multiplication table for a given number (between 1 and 10) using a for loop.
#
# Hint:
#
# Ask the user for a number between 1 and 10 .
# Use a for loop to iterate through the numbers from 1 to 10.
# For each iteration, calculate the product of the given number and the current number in the loop.
# Print the result in a readable format (e.g., 5 x 1 = 5).
# Ensure the program works correctly for any number between 1 and 10.
# Output Hint:
#
# - 4 x 1 = 4
# - 4 x 2 = 8
# - 4 x 3 = 12
# - 4 x 4 = 16
# - 4 x 5 = 20
# - 4 x 6 = 24
# - 4 x 7 = 28
# - 4 x 8 = 32
# - 4 x 9 = 36
# - 4 x 10 = 40

# %%
user_num = int(input("enter num to calculate table"))

if  1<= user_num <= 100:
    # for i in range (1,11): how 2x
        print(f"{user_num} x {i} = {user_num * i}")
# Out:
# 99 x 1 = 99
# 99 x 2 = 198
# 99 x 3 = 297
# 99 x 4 = 396
# 99 x 5 = 495
# 99 x 6 = 594
# 99 x 7 = 693
# 99 x 8 = 792
# 99 x 9 = 891
# 99 x 10 = 990

# %%
user_num = int(input("enter a num "))

if user_num  <=10:
    for f in range (1,11):
        print(f"{user_num} x {f} = {user_num * f}")

else:
    print("plz put right num")
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# Q2. Stop sending emails after 3 users (Using for loop and break)
#
# users = ["Ali", "Sara", "John", "Zara", "Mike"]
#
# Output:
#
# Email sent to Ali
#
# Email sent to Sara
#
# Email sent to John
#
# Limit reached. Stop sending emails.

# %%
users = ["Ali", "Sara", "John", "Zara", "Mike"]

for user in users:
    print(f"email sent to {user}")

# %%
users = ["Ali", "Sara", "John", "Zara", "Mike"]

email_sent = 0 
for user in users:
    print(f"Email sent to {user}")
    email_sent += 1
    if email_sent == 3:
        print("limt reached. stop sending emails")
        break
# Out:
# Email sent to Ali
# Email sent to Sara
# Email sent to John
# limt reached. stop sending emails

# %% [markdown]
# Q3. Stop monitoring temperature if critical temperature reached (Using for loop and break)
#
# temps = [22, 25, 30, 45, 28]
# critical = 40
#
# Ouput:
#
# Temperature: 22
#
# Temperature: 25
#
# Temperature: 30
#
# Critical temperature reached! Stop monitoring.

# %%
temps = [22, 25, 30, 45, 28]
critical = 40

for deg in temps:
    if deg >= critical:
        print(f"Critical temperature reached! Stop monitoring. {deg}")
        break
    print(f"Temperature under 40 {deg}")
# Out:
# Temperature under 40 22
# Temperature under 40 25
# Temperature under 40 30
# Critical temperature reached! Stop monitoring. 45

# %%
temps =[22,25,30,45,28]
critical = 40

for temp in temps:
    if temp >= critical:
        print("critical temperature! Reached")
        break

    print(f"Temperatue Monitoring: {temp}")
# Out:
# Temperatue Monitoring: 22
# Temperatue Monitoring: 25
# Temperatue Monitoring: 30
# critical temperature! Reached

# %% [markdown]
# Q4. Calculate total price of items in a shopping cart (Using For loop)
#
# cart = [100, 250, 50, 300]
#
# Output:
#
# Total Price: 700

# %%
cart = [100, 250, 50, 300]

prices = 0
for items in cart:
    prices += items

print(f" Total Price: {prices}")
# Out:
#  Total Price: 700

# %%
# cart = [100, 250, 50, 300]

# price = 0
# for item in cart:
#     price += item

# print(f" Total price: {price}")
# Out:
#  Total price: 700

# %% [markdown]
# Q5. Skip customers with unpaid bills (Using For loop and continue)
#
# customers = [
#     {"name": "Ali", "paid": True},
#
#     {"name": "Sara", "paid": False},
#
#     {"name": "John", "paid": True}
# ]
#
#
# Output:
#
# Access granted to: Ali
#
# Access granted to: John

# %%
customers = [
    {"name": "Ali", "paid": True},
    
    {"name": "Sara", "paid": False},
    
    {"name": "John", "paid": True}
]

for mtlb in customers:
    if mtlb ['paid'] == False:
        continue
    else:
        print(f"Acess Granted to {mtlb['name']}")
# Out:
# Acess Granted to Ali
# Acess Granted to John

# %%
customers = [
    {"name": "Ali", "paid": True},
    
    {"name": "Sara", "paid": False},
    
    {"name": "John", "paid": True}
]

for customer in customers:
    if customer ['paid'] == False:
        continue

    print(f"Acess Granted to {customer['name']}")
# Out:
# Acess Granted to Ali
# Acess Granted to John

# %% [markdown]
# Q6. Send personalized emails to a list of users (Using for loop)
#
# users = ["Ali", "Sara", "John"]
#
# Output:
#
# - Hello Ali, your subscription is active!
# - Hello Sara, your subscription is active!
# - Hello John, your subscription is active!

# %%
users = ["Ali", "Sara", "John"]

inpt = input("Enter Your Name: ")


if inpt in users:
    print(f"Hello {inpt}, your subscription is active!")
else:
    print("pay your subcription fee")
# Out:
# pay your subcription fee

# %%
users = ["Ali", "Sara", "John"]

num = 1
for user in users:
    print(f"{num}- Hallo {user}, your subscription is active!")
 
    num += 1
# Out:
# 1- Hallo Ali, your subscription is active!
# 2- Hallo Sara, your subscription is active!
# 3- Hallo John, your subscription is active!

# %% [markdown]
# Q7. Extract domain names from email list (Using for loop)
#
# emails = ["ali@gmail.com", "sara@yahoo.com", "john@hotmail.com"]
#
# Output:
#
# domains: ['gmail.com', 'yahoo.com', 'hotmail.com']

# %%
emails = ["ali@gmail.com", "sara@yahoo.com", "john@hotmail.com"]

for email in emails:
    print(f"Domains:" , email.split('@')[1])
# Out:
# Domains: gmail.com
# Domains: yahoo.com
# Domains: hotmail.com

# %%
emails = ["ali@gmail.com", "sara@yahoo.com", "john@hotmail.com"]

for email in emails:
    print(f"Domnains:" , email.split('@')[1])
# Out:
# Domnains: gmail.com
# Domnains: yahoo.com
# Domnains: hotmail.com

# %% [markdown]
# Q8. Print only overdue tasks (Using for loop)
#
# tasks = [
#     {"task": "Pay bills", "status": "done"},
#
#     {"task": "Submit report", "status": "pending"},
#
#     {"task": "Clean house", "status": "pending"}
# ]
#
#
# Ouput:
#
# Overdue: Submit report
#
# Overdue: Clean house

# %%
tasks = [
    {"task": "Pay bills", "status": "done"},
    
    {"task": "Submit report", "status": "pending"},
    
    {"task": "Clean house", "status": "pending"}
]

for taske in tasks:
    if taske ['status'] != "done":
        print(f"Overdue: {taske['task']}" )
# Out:
# Overdue: Submit report
# Overdue: Clean house

# %%
tasks = [
    {"task": "Pay bills", "status": "done"},
    
    {"task": "Submit report", "status": "pending"},
    
    {"task": "Clean house", "status": "pending"}
]

for task in tasks:
    if task ['status'] == 'done':
        continue

    print(f"overdue:" , task['task'])
# Out:
# overdue: Submit report
# overdue: Clean house

# %% [markdown]
# Q9. Extract names of employees with salary above 50,000
#
# employees = [
#     {"name": "Ali", "salary": 60000},
#
#     {"name": "Sara", "salary": 45000},
#
#     {"name": "John", "salary": 70000}
# ]
#
#
# Output:
#
# Ali earns above 50,000
#
# John earns above 50,000

# %%
employees = [
    {"name": "Ali", "salary": 60000},
    
    {"name": "Sara", "salary": 45000},
    
    {"name": "John", "salary": 70000}
]


for employe in employees:
    if employe ['salary'] >= 50000:
        print(f"{employe['name']} earns above 50,000 ")
# Out:
# Ali earns above 50,000
# John earns above 50,000

# %%
employees = [
    {"name": "Ali", "salary": 60000},
    
    {"name": "Sara", "salary": 45000},
    
    {"name": "John", "salary": 70000}
]

for employes in employees:
    if employes['salary'] >= 50000:
        print(f"{employes['name']} earns above 50,000")
# Out:
# Ali earns above 50,000
# John earns above 50,000

# %% [markdown]
# Q10. Skip weekends while printing workdays (Using for loop and continue)
#
# days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
#
# Output:
#
# Workday: Monday
#
# Workday: Tuesday
#
# Workday: Wednesday
#
# Workday: Thursday
#
# Workday: Friday

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

for day in days:
    if day in ["Saturday", "Sunday"]:
        continue
    print(f"workday: {day}")
# Out:
# workday: Monday
# workday: Tuesday
# workday: Wednesday
# workday: Thursday
# workday: Friday

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

for day in days:
    if day in ['Saturday' , 'Sunday']:
        continue

    print(f"Workday :", day)
# Out:
# Workday : Monday
# Workday : Tuesday
# Workday : Wednesday
# Workday : Thursday
# Workday : Friday

# %%
import os

# apne repo ka path daalo
path = r"C:\Users\user\Desktop\Git\GITDEMO\Assigment_4\.git\index.lock"

if os.path.exists(path):
    os.remove(path)
    print("index.lock file deleted ✅")
else:
    print("index.lock file not found 🚫")
# Out:
# index.lock file deleted ✅
