# %%
student = [87,67,54,76,87]

student[1]
# Out:
# 67

# %%
# directory how kisi bh string ki wsy kiki directory hoti he ?
#  ye to print only cod eor ouytput framwork dajngo se?
#  method or function
# dat hota kis foarm me konsa dat ye sub ide aho tool to ajyeng dat ko read
# short key excels
# list are mutable & str are imutable

#  trader like samjhany ke pasie hain fnance paat ho wagera usky liye kuchbhtech sales also
# iba wlak tees libaray meetup sattistics class python logic
# distribute sub jo likha he

# %%
# list slicing

marks = [23,67,98,0,45]

marks[0:]
# Out:
# [23, 67, 98, 0, 45]

# %%
# append list

List = [1,5,3]

List.append(7) #if need to 7 1 baad aye try accept lagau
List.insert(1,7)
List.sort()
print(List)
# Out:
# [1, 7, 5, 3]

# %%
# sort with reverse desending orders

List.sort(reverse=True)
print(List)

# list reverse
List1 = ['a','c','b','d','b']
List1.reverse()
print(List1)
# Out:
# [7, 5, 3, 1]
# ['d', 'b', 'c', 'a']

# %%
# remove & pop
list2 = ['d',1,3,5,3]
list2.remove(3)
print(list2)
list2.pop(0)
print(list2)
# Out:
# [1, 3, 5, 3]

# %%
# tuples in python

tup = (1,3,2,6,3,7)
print(tup)
print(type(tup))
print(tup.index(3))
print(tup.count(3))
# Out:
# (1, 3, 2, 6, 3, 7)
# <class 'tuple'>
# 1
# 2

# %%
# practice
movies = []
movies.append(input("enter 1 movie name"))
movies.append(input("enter 2 movie name"))
movies.append(input("enter 3 movie name"))

print(type(movies))

print(movies)
# Out:
# <class 'list'>
# ['fr', 'ty', 'ry']

# %%
user = input["enter word"]

if user.sort(reversed=True) == user.reverse():
    print("palindrome")
    if

# %%
user = input[entrer word]
copi = user.copy()
rev = copi.reversed()

if user == rev:
    print("palindrome")
else:
    print("not palindrom")
# Out:
#   Cell In[47], line 1
#     user = input[entrer word]
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pl = [1,2,1]
npl = [1,2,3]

copi = npl.copy()
copi.reverse()

if copi == npl:
    print('palindrome')
else:
    print('not palindrom')
# Out:
# not palindrom

# %%
# 3question

ranks = ['A','E','D','A','C','D','A']

print(ranks.count('A'))
# Out:
# 3

# %%
ranks.sort()
print(ranks)
# Out:
# ['A', 'A', 'A', 'C', 'D', 'D', 'E']

# %%
# User se 5 fruits ka naam lo aur ek list me store karo.
# Phir print karo 1st aur last fruit.

fruits = []
fruits.append(input('enter 1 fruit name '))
fruits.append(input('enter 2 fruit name '))
fruits.append(input('enter 3 fruit name '))
fruits.append(input('enter 4 fruit name '))
fruits.append(input('enter 5 fruit name '))

print(fruits[0])
print(fruits[4])
# Out:
# ap
# rt

# %%
# Ek list banao numbers ki [2, 4, 6, 8, 10]
# User se ek number lo.
# Agar wo list me hai → print("Found")
# warna → print("Not found")

# (Hint: use in keyword)

numbers = [2, 4, 6, 8, 10] 

n_u = int(input('enter number'))

if n_u in numbers:
    print('found',n_u)
else:
    print('not found',n_u)
# Out:
# found 4

# %%
# Ek empty list lo.
# User se 3 names input lo (bina loop).
# Har input ko append() se list me daalo.
# Phir puri list print karo.


emp = []

emp.append(input('enter 1 name'))
emp.append(input('enter 2 name'))
emp.append(input('enter 3 name'))

print(emp)
# Out:
# ['3', '6', '9']

# %%
# Ek list banao [10, 20, 30, 40, 50]
# Slicing use karke print karo:

# Pehle 3 numbers

# Aakhri 2 numbers

nms = [10, 20, 30, 40, 50]

print(nms[0:3])
print(nms[-2:])
# Out:
# [10, 20, 30]
# [40, 50]

# %%
# Ek list banao [3, 1, 4, 2, 5]
# Use sort() karke ascending aur descending dono order me print karo

banali = [3, 1, 4, 2, 5]

banali.sort(reverse=False)
print(banali)
banali.sort(reverse=True)
print(banali)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]

# %%
# Ek list banao [10, 20, 30, 40, 50]
# Middle number remove karo (remove() ya pop() se).
# Updated list print karo.

banau = [10, 20, 30, 40, 50]

banau.pop()
print()
# Out:
# [10, 20, 30, 50]

# %%
# User se ek sentence lo.
# split() use karke usko list me convert karo.
# Phir len() se print karo total words.

user = input('give me a sentence')

iny = user.split(user)
print(iny)
print(len(iny))
print(type(iny))
# Out:
# ['', '']
# 2
# <class 'list'>

# %%
# Ek list banao [5, 10, 15, 20, 25]
# Uska first, middle, aur last element print karo (sirf indexing se).

ek = [2, 5, 8, 3, 9]

print(ek[0])
print(ek[2])
print(ek[4])
# Out:
# 2
# 8
# 9

# %%
# Ek list banao ['apple', 'banana', 'grapes', 'mango', 'orange']
# User se ek fruit input lo.
# Agar wo list me hai → print("Available")
# warna → print("Not available").

banau = ['apple', 'banana', 'grapes', 'mango', 'orange']

de_yr = input('enter your fav fruit name')
if de_yr in banau:
    print('Available:',de_yr)
else:
    print('Not Available',de_yr)
# Out:
# Available: grapes

# %% [markdown]
# app problem solve code se hr code me bus yehi ab se or live code dajango ya kon

# %% [markdown]
# ## Smart Sentence Analyzer

# %%
# Out:
# total words: 3
# sentence start with vowel:

# %%
# User se kuch basic details lena (jaise name, email, password, city)
# aur unke base par validation karna — sab kuch strings, conditions aur list ke through (loop ke bina).



f_name = input("enter full name: ")
w_name = f_name.split()

if " " in f_name:
    print("full name detected")
if f_name[0].lower() in "aeiou":
    print("Nice start!")
if  len(f_name) <=3:
    print("too short")
# Out:
# Nice start!
# too short

# %%
# email validation

uer = input("enter email adress:")
if '@' and '.' in uer:
    print('Valid email format')
else:
    print('Invalid email')

if '.com' in uer: #if specifc nh hota com or edu to kesy krty hm endwith to kaam nh krta haina
    print('Looks like a personal email.')
elif '.edu' in uer:
    print('Educational email detected.')
# Out:
# Valid email format
# Looks like a personal email.

# %%
c_w = ['Khi','Lr','Isl']
city = input('enter your city name')


if city[0] == city[0].upper():
    print('Proper format')
else:
    print('Please capitalize first letter')

if city in c_w:
    print('Major city detected.')
# Out:
# Please capitalize first letter
